# %%
# !pip install transformers vllm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.3/265.3 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 MB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 83.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 85.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.1 MB/s eta 0:00:00
# ...

# %%
from vllm import LLM
from huggingface_hub import interpreter_login
import gc, torch
interpreter_login()
# Out:
# INFO 03-19 17:22:21 [__init__.py:256] Automatically detected platform cuda.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# ...

# %%
prompts = ["Hello, my name is", "The capital of France is"]  # Sample prompts.
llm = LLM(model="gpt2",
          tensor_parallel_size=1,
          enforce_eager=True,
          max_model_len=1024)

outputs = llm.generate(prompts)  # Generate texts from the prompts.
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# INFO 03-19 15:44:15 [config.py:2595] Downcasting torch.float32 to torch.float16.
# INFO 03-19 15:44:31 [config.py:583] This model supports multiple tasks: {'score', 'embed', 'generate', 'classify', 'reward'}. Defaulting to 'generate'.
# WARNING 03-19 15:44:31 [arg_utils.py:1754] Compute Capability < 8.0 is not supported by the V1 Engine. Falling back to V0.
# WARNING 03-19 15:44:31 [cuda.py:95] To see benefits of async output processing, enable CUDA graph. Since, enforce-eager is enabled, async output processor cannot be used
# ...

# %%
outputs
# Out:
# [RequestOutput(request_id=0, prompt='Hello, my name is', prompt_token_ids=[15496, 11, 616, 1438, 318], encoder_prompt=None, encoder_prompt_token_ids=None, prompt_logprobs=None, outputs=[CompletionOutput(index=0, text=' Misuichi Uzae, and I am currently in the process of creating the', token_ids=(14136, 84, 16590, 40919, 3609, 11, 290, 314, 716, 3058, 287, 262, 1429, 286, 4441, 262), cumulative_logprob=None, logprobs=None, finish_reason=length, stop_reason=None)], finished=True, metrics=RequestMetrics(arrival_time=1742399092.1887743, last_token_time=1742399092.5311027, first_scheduled_time=1742399092.203964, first_token_time=1742399092.2459316, time_in_queue=0.015189647674560547, finished_time=1742399092.5313253, scheduler_time=0.002708766000068863, model_forward_time=None, model_execute_time=None, spec_token_acceptance_counts=[0]), lora_request=None, num_cached_tokens=0, multi_modal_placeholders={}),
# ...

# %%
del llm
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# # To use vLLM for online serving, you can start an OpenAI API-compatible server via:

# %%
# !curl ipv4.icanhazip.com
# Out:
# 34.125.212.201

# %%
! python -m vllm.entrypoints.openai.api_server --host 127.0.0.1 --port 8888 --model openai-community/gpt2 & npx localtunnel --port 8888
# Out:
# ⠙⠹⠸⠼⠴⠦⠧Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y) y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼2025-03-19 17:23:07.024738: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742404987.047174    1618 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742404987.053451    1618 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋INFO 03-19 17:23:10 [__init__.py:256] Automatically detected platform cuda.
# INFO 03-19 17:23:11 [api_server.py:977] vLLM API server version 0.8.0
# ...

# %%
# !curl https://itchy-impalas-travel.loca.lt/v1/completions -H "Content-Type: application/json" -d '{"model": "openai-community/gpt2","prompt": "Moscow is the capital","max_tokens": 10,"temperature": 0.7}'
